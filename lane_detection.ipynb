# %%
import cv2
from cv2 import polylines
import numpy as np
import matplotlib.pyplot as plt

# %%
images_path = 'processed_dataset/training_data/train_images.npy'

# %%
images = np.load(images_path, allow_pickle = True)

# %%
cv2.imshow("image", images[0])
cv2.waitKey(1)
cv2.destroyAllWindows()

# %%
plt.imshow(images[0])

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-b579d5ec92bd> in <module>
#      10 thickness = 2
#      11
# ---> 12 pts = pts.reshape((-1, 1, 2))
#      13
#      14 # Using cv2.polylines() method
#
# NameError: name 'pts' is not defined
